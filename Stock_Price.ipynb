# %% [markdown]
# ## Importing Libraries and fetching data

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline

# %%
from datetime import datetime

# The stocks we'll use for this analysis
stocks_list = ['AAPL', 'GOOG', 'MSFT', 'AMZN']

end = datetime.now()
start = datetime(end.year - 1, end.month, end.day)

for stock in stocks_list:
    globals()[stock] = yf.download(stock, start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ### Apple Data

# %%
AAPL.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-09-11  180.070007  180.300003  177.339996  179.360001  178.446869
# 2023-09-12  179.490005  180.130005  174.820007  176.300003  175.402451
# 2023-09-13  176.509995  177.300003  173.979996  174.210007  173.323090
# 2023-09-14  174.000000  176.100006  173.580002  175.740005  174.845306
# 2023-09-15  176.479996  176.500000  173.820007  175.009995  174.119003
#
#                Volume
# Date
# 2023-09-11   58953100
# 2023-09-12   90370200
# 2023-09-13   84267900
# 2023-09-14   60895800
# 2023-09-15  109205100

# %%
print(AAPL.dtypes)
# Out:
# Open              float64
# High              float64
# Low               float64
# Close             float64
# Adj Close         float64
# Volume              int64
# company_name       object
# MA for 10 days    float64
# MA for 20 days    float64
# MA for 50 days    float64
# Daily Return      float64
# dtype: object

# %% [markdown]
# ### Google data

# %%
GOOG.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-09-11  137.380005  138.264008  136.550003  137.740005  137.402573
# 2023-09-12  137.130005  137.639999  135.929993  136.070007  135.736664
# 2023-09-13  135.899994  137.699997  134.929993  137.500000  137.163162
# 2023-09-14  138.389999  139.550003  137.059998  138.990005  138.649506
# 2023-09-15  138.800003  139.360001  137.179993  138.300003  137.961197
#
#               Volume
# Date
# 2023-09-11  17180800
# 2023-09-12  15212900
# 2023-09-13  16394900
# 2023-09-14  19064600
# 2023-09-15  48947600

# %% [markdown]
# ### Microsoft data

# %%
MSFT.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-09-11  337.239990  338.420013  335.429993  337.940002  335.422333
# 2023-09-12  335.820007  336.790009  331.480011  331.769989  329.298248
# 2023-09-13  331.309998  336.850006  331.170013  336.059998  333.556305
# 2023-09-14  339.149994  340.859985  336.570007  338.700012  336.176636
# 2023-09-15  336.920013  337.399994  329.649994  330.220001  327.759827
#
#               Volume
# Date
# 2023-09-11  16583300
# 2023-09-12  17565500
# 2023-09-13  16544400
# 2023-09-14  20267000
# 2023-09-15  37666900

# %% [markdown]
# ### Amazon data

# %%
AMZN.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-09-11  138.750000  143.619995  138.639999  143.100006  143.100006
# 2023-09-12  142.320007  143.000000  140.610001  141.229996  141.229996
# 2023-09-13  140.949997  144.979996  140.869995  144.850006  144.850006
# 2023-09-14  145.080002  145.860001  142.949997  144.720001  144.720001
# 2023-09-15  142.690002  143.570007  140.089996  140.389999  140.389999
#
#                Volume
# Date
# 2023-09-11   56764500
# 2023-09-12   42668500
# 2023-09-13   60465200
# 2023-09-14   64033600
# 2023-09-15  102861700

# %% [markdown]
# ### Combined data

# %%
company_list = [AAPL, GOOG, MSFT, AMZN]
company_name = ["APPLE", "GOOGLE", "MICROSOFT", "AMAZON"]

for company, com_name in zip(company_list, company_name):
    company["company_name"] = com_name
    
df = pd.concat(company_list, axis=0)
df.tail(10)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-08-26  176.699997  177.470001  174.300003  175.500000  175.500000
# 2024-08-27  174.149994  174.889999  172.250000  173.119995  173.119995
# 2024-08-28  173.690002  173.690002  168.919998  170.800003  170.800003
# 2024-08-29  173.220001  174.289993  170.809998  172.119995  172.119995
# 2024-08-30  172.779999  178.899994  172.600006  178.500000  178.500000
# 2024-09-03  177.550003  178.259995  175.259995  176.250000  176.250000
# 2024-09-04  174.479996  175.979996  172.539993  173.330002  173.330002
# 2024-09-05  175.000000  179.880005  175.000000  177.889999  177.889999
# 2024-09-06  177.240005  178.380005  171.160004  171.389999  171.389999
# 2024-09-09  174.529999  175.850006  173.509995  175.399994  175.399994
#
#               Volume company_name
# Date
# 2024-08-26  22366200       AMAZON
# 2024-08-27  29842000       AMAZON
# 2024-08-28  29045000       AMAZON
# 2024-08-29  26407800       AMAZON
# 2024-08-30  43429400       AMAZON
# 2024-09-03  37817500       AMAZON
# 2024-09-04  30309200       AMAZON
# 2024-09-05  40170500       AMAZON
# 2024-09-06  41466500       AMAZON
# 2024-09-09  28983000       AMAZON

# %%
AAPL.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  251.000000  251.000000  251.000000  251.000000  251.000000
# mean   191.182111  192.947690  189.538884  191.313825  190.811625
# std     18.951879   19.187765   18.513422   18.872394   19.047861
# min    165.350006  166.399994  164.080002  165.000000  164.585999
# 25%    175.545006  177.395004  173.919998  175.615005  174.752983
# 50%    187.509995  188.669998  186.289993  187.429993  186.731415
# 75%    197.214996  199.009995  195.945000  198.035004  197.286362
# max    236.479996  237.229996  233.089996  234.820007  234.548523
#
#              Volume
# count  2.510000e+02
# mean   5.948858e+07
# std    2.490366e+07
# min    2.404830e+07
# 25%    4.592600e+07
# 50%    5.337730e+07
# 75%    6.580375e+07
# max    2.464214e+08

# %%
plt.figure(figsize=(15, 10))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    company['Adj Close'].plot()
    plt.ylabel('Adj Close')
    plt.xlabel('Years')
    plt.title(f"Closing Price of {stocks_list[i - 1]}")
    
plt.tight_layout()

# %%
ma_day = [10, 20, 50]

for ma in ma_day:
    for company in company_list:
        column_name = f"MA for {ma} days"
        company[column_name] = company['Adj Close'].rolling(ma).mean()
        
company.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-09-03  177.550003  178.259995  175.259995  176.250000  176.250000
# 2024-09-04  174.479996  175.979996  172.539993  173.330002  173.330002
# 2024-09-05  175.000000  179.880005  175.000000  177.889999  177.889999
# 2024-09-06  177.240005  178.380005  171.160004  171.389999  171.389999
# 2024-09-09  174.529999  175.850006  173.509995  175.399994  175.399994
#
#               Volume company_name  MA for 10 days  MA for 20 days  \
# Date
# 2024-09-03  37817500       AMAZON      175.845000        172.7945
# 2024-09-04  30309200       AMAZON      175.289999        173.3645
# 2024-09-05  40170500       AMAZON      175.067999        174.1205
# 2024-09-06  41466500       AMAZON      174.593999        174.4000
# 2024-09-09  28983000       AMAZON      174.429999        174.8230
#
#             MA for 50 days
# Date
# 2024-09-03        182.2566
# 2024-09-04        182.0118
# 2024-09-05        181.8428
# 2024-09-06        181.3984
# 2024-09-09        180.9494

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
fig.set_figheight(10)
fig.set_figwidth(15)

AAPL[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[0,0])
axes[0,0].set_title('APPLE')

GOOG[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[0,1])
axes[0,1].set_title('GOOGLE')

MSFT[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[1,0])
axes[1,0].set_title('MICROSOFT')

AMZN[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[1,1])
axes[1,1].set_title('AMAZON')

fig.tight_layout()

# %%
combined_df = pd.concat(company_list, axis=0)
combined_df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-09-03  177.550003  178.259995  175.259995  176.250000  176.250000
# 2024-09-04  174.479996  175.979996  172.539993  173.330002  173.330002
# 2024-09-05  175.000000  179.880005  175.000000  177.889999  177.889999
# 2024-09-06  177.240005  178.380005  171.160004  171.389999  171.389999
# 2024-09-09  174.529999  175.850006  173.509995  175.399994  175.399994
#
#               Volume company_name  MA for 10 days  MA for 20 days  \
# Date
# 2024-09-03  37817500       AMAZON      175.845000        172.7945
# 2024-09-04  30309200       AMAZON      175.289999        173.3645
# 2024-09-05  40170500       AMAZON      175.067999        174.1205
# 2024-09-06  41466500       AMAZON      174.593999        174.4000
# 2024-09-09  28983000       AMAZON      174.429999        174.8230
#
#             MA for 50 days
# Date
# 2024-09-03        182.2566
# 2024-09-04        182.0118
# 2024-09-05        181.8428
# 2024-09-06        181.3984
# 2024-09-09        180.9494

# %%
for company in company_list:
    company['Daily Return'] = company['Adj Close'].pct_change()

fig, axes = plt.subplots(nrows=2, ncols=2)
fig.set_figheight(10)
fig.set_figwidth(15)

AAPL['Daily Return'].plot(ax=axes[0,0], legend=True, marker='o')
axes[0,0].set_title('APPLE')

GOOG['Daily Return'].plot(ax=axes[0,1], legend=True, marker='o')
axes[0,1].set_title('GOOGLE')

MSFT['Daily Return'].plot(ax=axes[1,0], legend=True, marker='o')
axes[1,0].set_title('MICROSOFT')

AMZN['Daily Return'].plot(ax=axes[1,1], legend=True, marker='o')
axes[1,1].set_title('AMAZON')

fig.tight_layout()

# %%
combined_df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-09-03  177.550003  178.259995  175.259995  176.250000  176.250000
# 2024-09-04  174.479996  175.979996  172.539993  173.330002  173.330002
# 2024-09-05  175.000000  179.880005  175.000000  177.889999  177.889999
# 2024-09-06  177.240005  178.380005  171.160004  171.389999  171.389999
# 2024-09-09  174.529999  175.850006  173.509995  175.399994  175.399994
#
#               Volume company_name  MA for 10 days  MA for 20 days  \
# Date
# 2024-09-03  37817500       AMAZON      175.845000        172.7945
# 2024-09-04  30309200       AMAZON      175.289999        173.3645
# 2024-09-05  40170500       AMAZON      175.067999        174.1205
# 2024-09-06  41466500       AMAZON      174.593999        174.4000
# 2024-09-09  28983000       AMAZON      174.429999        174.8230
#
#             MA for 50 days
# Date
# 2024-09-03        182.2566
# 2024-09-04        182.0118
# 2024-09-05        181.8428
# 2024-09-06        181.3984
# 2024-09-09        180.9494

# %%
plt.figure(figsize=(12, 9))

for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    company['Daily Return'].hist(bins=50)
    plt.xlabel('Daily Return')
    plt.ylabel('Counts')
    plt.title(f'{company_name[i - 1]}')
    
plt.tight_layout()

# %%
# Closing Price of each company at each day
closing_df = yf.download(stocks_list, start=start, end=end)['Adj Close']
closing_df.tail()
# Out:
# [*********************100%***********************]  4 of 4 completed
# Ticker                           AAPL        AMZN        GOOG        MSFT
# Date
# 2024-09-03 00:00:00+00:00  222.770004  176.250000  158.401489  409.440002
# 2024-09-04 00:00:00+00:00  220.850006  173.330002  157.602539  408.899994
# 2024-09-05 00:00:00+00:00  222.380005  177.889999  158.391510  408.390015
# 2024-09-06 00:00:00+00:00  220.820007  171.389999  151.930008  401.700012
# 2024-09-09 00:00:00+00:00  220.910004  175.399994  149.539993  405.720001

# %%
# Dataframe which returns stock returns
stock_returns = closing_df.pct_change()
stock_returns.tail()
# Out:
# Ticker                         AAPL      AMZN      GOOG      MSFT
# Date
# 2024-09-03 00:00:00+00:00 -0.027205 -0.012605 -0.039368 -0.018459
# 2024-09-04 00:00:00+00:00 -0.008619 -0.016567 -0.005044 -0.001319
# 2024-09-05 00:00:00+00:00  0.006928  0.026308  0.005006 -0.001247
# 2024-09-06 00:00:00+00:00 -0.007015 -0.036539 -0.040794 -0.016381
# 2024-09-09 00:00:00+00:00  0.000408  0.023397 -0.015731  0.010007

# %%
stock_returns.replace([float('inf'), float('-inf')], pd.NA, inplace=True)
cleaned_returns = stock_returns.dropna()

# %%
# Comparing Google to itself should show a perfectly linear relationship
plt.scatter(cleaned_returns['GOOG'], cleaned_returns['GOOG'], color='seagreen')
plt.title('Google v/s Google  Daily Returns')
plt.xlabel('GOOG Returns')
plt.ylabel('GOOG Returns')
plt.show()

# %%
# Comparing Google to Microsoft
plt.scatter(cleaned_returns['MSFT'], cleaned_returns['GOOG'], color='seagreen')
plt.title('Google v/s Microsoft  Daily Returns')
plt.xlabel('MSFT Returns')
plt.ylabel('GOOG Returns')
plt.show()

# %%
sns.pairplot(cleaned_returns, kind='reg')

# %%
stock_returns.corr()
# Out:
# Ticker      AAPL      AMZN      GOOG      MSFT
# Ticker
# AAPL    1.000000  0.390427  0.423069  0.490467
# AMZN    0.390427  1.000000  0.568345  0.624887
# GOOG    0.423069  0.568345  1.000000  0.543695
# MSFT    0.490467  0.624887  0.543695  1.000000

# %%
plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
sns.heatmap(stock_returns.corr(), annot=True, cmap='summer')
plt.title('Correlation of stock return')
# Out:
# Text(0.5, 1.0, 'Correlation of stock return')

# %%
stock_returns.isna().sum()
# Out:
# Ticker
# AAPL    1
# AMZN    1
# GOOG    1
# MSFT    1
# dtype: int64

# %%
returns = stock_returns.dropna()

area = np.pi * 15

plt.figure(figsize=(10, 6))
plt.scatter(returns.mean(), returns.std(), s=area)
plt.xlabel('Expected return')
plt.ylabel('Risk')

for label, x, y in zip(returns.columns, returns.mean(), returns.std()):
    plt.annotate(
        label,            # The label (company name)
        xy=(x, y),        # The (x, y) coordinates of the point
        xytext=(5, 5),    # Offset the label by (5, 5) points
        textcoords='offset points',  # Coordinate system for xytext
        ha='right',       # Horizontal alignment of the label
        va='bottom'       # Vertical alignment of the label
    )

# %%
df = yf.download('AAPL', start='2014-01-01', end=datetime.now())
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-01-02   19.845715   19.893929   19.715000   19.754642   17.253256
# 2014-01-03   19.745001   19.775000   19.301071   19.320715   16.874273
# 2014-01-06   19.194643   19.528570   19.057142   19.426071   16.966293
# 2014-01-07   19.440001   19.498571   19.211430   19.287144   16.844948
# 2014-01-08   19.243214   19.484285   19.238930   19.409286   16.951633
# ...                ...         ...         ...         ...         ...
# 2024-09-03  228.550003  229.000000  221.169998  222.770004  222.770004
# 2024-09-04  221.660004  221.779999  217.479996  220.850006  220.850006
# 2024-09-05  221.630005  225.479996  221.520004  222.380005  222.380005
# 2024-09-06  223.949997  225.240005  219.770004  220.820007  220.820007
# 2024-09-09  220.820007  221.270004  216.710007  220.910004  220.910004
#
#                Volume
# Date
# 2014-01-02  234684800
# 2014-01-03  392467600
# 2014-01-06  412610800
# 2014-01-07  317209200
# 2014-01-08  258529600
# ...               ...
# 2024-09-03   50190600
# 2024-09-04   43840200
# 2024-09-05   36615400
# 2024-09-06   48423000
# 2024-09-09   67069600
#
# [2689 rows x 6 columns]

# %%
plt.figure(figsize=(14,6))
plt.title('Close Price History')
plt.plot(df['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()

# %%
data = df.filter(['Close'])
len(data)
dataset = data.values

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)

scaled_data
# Out:
# array([[0.00878163],
#        [0.0067817 ],
#        [0.00726728],
#        ...,
#        [0.94266506],
#        [0.93547517],
#        [0.93588995]])

# %%
training_data_len = int(np.ceil( len(dataset) * .95 ))
training_data_len
# Out:
# 2555

# %%
train_data = scaled_data[0:int(training_data_len), :]
# Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])
    if i == 60:
        print(x_train)
        print(y_train)
        
# Convert the x_train and y_train to numpy arrays since NumPy arrays are the standard input format for most deep learning libraries.
x_train, y_train = np.array(x_train), np.array(y_train)

# Reshape the data because RNNs, including LSTMs, expect input data in 3D format
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
# Out:
# [array([0.00878163, 0.0067817 , 0.00726728, 0.00662697, 0.00718992,
#        0.00604756, 0.00545828, 0.00591753, 0.00767221, 0.00947791,
#        0.00896599, 0.00673067, 0.00811335, 0.00851498, 0.00928368,
#        0.00761953, 0.00834872, 0.00110615, 0.00015967, 0.        ,
#        0.00013497, 0.00028806, 0.00148308, 0.00210858, 0.00209541,
#        0.00327562, 0.00480809, 0.00595539, 0.00594879, 0.00734958,
#        0.00727715, 0.00760636, 0.00618747, 0.00516363, 0.00419247,
#        0.00457105, 0.00366739, 0.0028921 , 0.00459082, 0.00435543,
#        0.00460563, 0.00517845, 0.00536281, 0.00509779, 0.00504677,
#        0.00512578, 0.00597678, 0.00606237, 0.00508133, 0.0041003 ,
#        0.00443773, 0.00520478, 0.00518174, 0.00476036, 0.00544675,
#        0.00648706, 0.00744176, 0.00658417, 0.00620229, 0.00610352])]
# [0.00608377751983194]

# %%
x_train
# Out:
# array([[[0.00878163],
#         [0.0067817 ],
#         [0.00726728],
#         ...,
#         [0.00658417],
#         [0.00620229],
#         [0.00610352]],
#
#        [[0.0067817 ],
#         [0.00726728],
#         [0.00662697],
#         ...,
#         [0.00620229],
#         [0.00610352],
#         [0.00608378]],
#
#        [[0.00726728],
#         [0.00662697],
#         [0.00718992],
#         ...,
#         [0.00610352],
#         [0.00608378],
#         [0.00689198]],
#
#        ...,
#
#        [[0.79246041],
#         [0.79527186],
#         [0.79052468],
#         ...,
#         [0.75452905],
#         [0.75803187],
#         [0.76748009]],
#
#        [[0.79527186],
#         [0.79052468],
#         [0.79319786],
#         ...,
#         [0.75803187],
#         [0.76748009],
#         [0.75895364]],
#
#        [[0.79052468],
#         [0.79319786],
#         [0.7991434 ],
#         ...,
#         [0.76748009],
#         [0.75895364],
#         [0.75268551]]])

# %%
x_train.shape
# Out:
# (2495, 60, 1)

# %%
y_train
# Out:
# array([0.00608378, 0.00689198, 0.00704012, ..., 0.75895364, 0.75268551,
#        0.75946062])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Input

# %%
model = Sequential()

# Define the input layer explicitly
model.add(Input(shape=(x_train.shape[1], 1)))

# Add the LSTM layers
model.add(LSTM(128, return_sequences=True))
model.add(LSTM(64, return_sequences=False))

# Add the Dense layers
model.add(Dense(25))
model.add(Dense(1))

# %%
# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')
# Train the model
model.fit(x_train, y_train, batch_size=1, epochs=1)
# Out:
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 31s 11ms/step - loss: 0.0018

# %%
training_data_len - 60
# Out:
# 2495

# %%
# Create the testing data set
# Create a new array containing scaled values from index 1543 to 2002 
test_data = scaled_data[training_data_len - 60:, :]
len(test_data)
# Out:
# 194

# %%
x_test = []
y_test = dataset[training_data_len:, :]
for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])

x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1 ))

# %%
x_test
# Out:
# array([[[0.79319786],
#         [0.7991434 ],
#         [0.7908012 ],
#         ...,
#         [0.75895364],
#         [0.75268551],
#         [0.75946062]],
#
#        [[0.7991434 ],
#         [0.7908012 ],
#         [0.8091908 ],
#         ...,
#         [0.75268551],
#         [0.75946062],
#         [0.7538838 ]],
#
#        [[0.7908012 ],
#         [0.8091908 ],
#         [0.80412104],
#         ...,
#         [0.75946062],
#         [0.7538838 ],
#         [0.75079584]],
#
#        ...,
#
#        [[0.80780811],
#         [0.87247121],
#         [0.89975606],
#         ...,
#         [0.97317607],
#         [0.94446254],
#         [0.93561343]],
#
#        [[0.87247121],
#         [0.89975606],
#         [0.90514848],
#         ...,
#         [0.94446254],
#         [0.93561343],
#         [0.94266506]],
#
#        [[0.89975606],
#         [0.90514848],
#         [0.89708288],
#         ...,
#         [0.93561343],
#         [0.94266506],
#         [0.93547517]]])

# %%
# Get the models predicted price values 
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)

# Get the root mean squared error (RMSE)
rmse = np.sqrt(np.mean(((predictions - y_test) ** 2)))
rmse
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step
# 11.152761098723241

# %%
# Assuming 'data' is a DataFrame containing the stock prices
train = data[:training_data_len]
valid = data[training_data_len:].copy()  # Create a copy of the validation data

# Add predictions to the validation DataFrame
valid['Predictions'] = predictions

# Visualize the data
plt.figure(figsize=(16, 6))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)

# Plot training data
plt.plot(train['Close'], label='Train')
# Plot actual and predicted validation data
plt.plot(valid['Close'], label='Val')
plt.plot(valid['Predictions'], label='Predictions')

plt.legend(loc='lower right')
plt.show()

# %%
valid
# Out:
#                  Close  Predictions
# Date
# 2024-02-28  181.419998   193.153824
# 2024-02-29  180.750000   192.991699
# 2024-03-01  179.660004   192.643738
# 2024-03-04  175.100006   192.033142
# 2024-03-05  170.119995   190.383301
# ...                ...          ...
# 2024-09-03  222.770004   239.261810
# 2024-09-04  220.850006   238.224838
# 2024-09-05  222.380005   236.335846
# 2024-09-06  220.820007   234.848923
# 2024-09-09  220.910004   233.464264
#
# [134 rows x 2 columns]

# %%
def get_stock_price(stock_symbol, target_date):
    # Define the date range for fetching historical data
    end_date = pd.to_datetime(target_date)
    start_date = end_date - pd.DateOffset(years=1)  # Fetch data for the past year or adjust as needed

    # Fetch historical data from yfinance
    historical_data = yf.download(stock_symbol, start=start_date, end=end_date + pd.DateOffset(days=1))

    # Ensure the data is sorted by date
    historical_data.index = pd.to_datetime(historical_data.index)
    historical_data.sort_index(inplace=True)

    # Check if the target date is in the DataFrame index
    if target_date in historical_data.index:
        actual_price = historical_data.loc[target_date]['Close']
        return actual_price
    else:
        return None

# %%
from datetime import datetime, timedelta
def calculate_start_date(prediction_date_str, window_days):
    # Convert prediction_date_str to datetime object
    prediction_date = datetime.strptime(prediction_date_str, '%Y-%m-%d')
    
    # Calculate the start date by subtracting the window_days from the prediction_date
    start_date = prediction_date - timedelta(days=window_days)
    
    # Return the start date in string format
    return start_date.strftime('%Y-%m-%d')

# %%
# Define the stock symbol and prediction date
stock_symbol = 'META'
prediction_date = '2017-07-20'
start_date = calculate_start_date(prediction_date, 60)
start_date
# Out:
# '2017-05-21'

# %%
historical_data = yf.download(stock_symbol, start=start_date, end=prediction_date)
historical_data = historical_data.sort_index()

# Prepare the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(historical_data[['Close']])

sequence_length = 60
last_sequence = scaled_data[-sequence_length:]
x_input = np.array([last_sequence])
x_input = np.reshape(x_input, (x_input.shape[0], x_input.shape[1], 1))
historical_data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-05-22  148.080002  148.589996  147.690002  148.240005  147.936005
# 2017-05-23  148.520004  148.809998  147.250000  148.070007  147.766357
# 2017-05-24  148.509995  150.229996  148.419998  150.039993  149.732300
# 2017-05-25  150.300003  152.589996  149.949997  151.960007  151.648376
# 2017-05-26  152.229996  152.250000  151.149994  152.130005  151.818024
# 2017-05-30  151.970001  152.899994  151.639999  152.380005  152.067520
# 2017-05-31  152.699997  153.350006  151.089996  151.460007  151.149399
# 2017-06-01  151.750000  152.289993  150.300003  151.529999  151.219254
# 2017-06-02  151.850006  153.630005  151.300003  153.610001  153.294983
# 2017-06-05  153.639999  154.710007  153.410004  153.630005  153.314957
# 2017-06-06  153.410004  154.520004  152.479996  152.809998  152.496628
# 2017-06-07  153.270004  153.750000  152.339996  153.119995  152.805984
# 2017-06-08  154.080002  154.729996  153.100006  154.710007  154.392746
# 2017-06-09  154.770004  155.589996  146.610001  149.600006  149.293228
# 2017-06-12  148.169998  149.199997  144.559998  148.440002  148.135590
# 2017-06-13  150.149994  151.179993  148.899994  150.679993  150.371002
# 2017-06-14  151.259995  152.399994  149.050003  150.250000  149.941879
# 2017-06-15  147.669998  150.039993  146.369995  149.800003  149.492813
# 2017-06-16  149.589996  150.830002  148.600006  150.639999  150.331070
# 2017-06-19  151.710007  153.570007  151.710007  152.869995  152.556503
# 2017-06-20  152.880005  153.839996  152.210007  152.250000  151.937790
# 2017-06-21  152.360001  154.080002  151.880005  153.910004  153.594376
# 2017-06-22  153.009995  154.550003  152.910004  153.399994  153.085419
# 2017-06-23  152.720001  155.199997  152.649994  155.070007  154.752014
# 2017-06-26  156.250000  156.500000  153.199997  153.589996  153.275024
# 2017-06-27  152.839996  153.309998  150.389999  150.580002  150.271210
# 2017-06-28  150.919998  153.470001  149.860001  153.240005  152.925751
# 2017-06-29  152.279999  152.500000  148.919998  151.039993  150.730255
# 2017-06-30  151.899994  151.919998  150.059998  150.979996  150.670380
# 2017-07-03  151.720001  152.149994  147.800003  148.429993  148.125610
# 2017-07-05  149.000000  150.850006  148.130005  150.339996  150.031693
# 2017-07-06  149.029999  150.039993  148.000000  148.820007  148.514816
# 2017-07-07  149.250000  151.990005  149.190002  151.440002  151.129440
# 2017-07-10  151.690002  153.979996  151.509995  153.500000  153.185211
# 2017-07-11  153.369995  155.419998  152.910004  155.270004  154.951599
# 2017-07-12  156.490005  159.160004  156.199997  158.899994  158.574142
# 2017-07-13  158.740005  159.779999  158.419998  159.259995  158.933395
# 2017-07-14  160.130005  160.320007  159.330002  159.970001  159.641937
# 2017-07-17  160.250000  160.779999  158.809998  159.729996  159.402435
# 2017-07-18  159.660004  163.729996  159.419998  162.860001  162.526031
# 2017-07-19  163.589996  165.699997  163.169998  164.139999  163.803406
#
#               Volume
# Date
# 2017-05-22  12586700
# 2017-05-23  12817800
# 2017-05-24  17862400
# 2017-05-25  19891400
# 2017-05-26  14996200
# 2017-05-30  13226000
# 2017-05-31  18023900
# 2017-06-01  14530600
# 2017-06-02  16854400
# 2017-06-05  12520400
# 2017-06-06  13457100
# 2017-06-07  12066700
# 2017-06-08  17799400
# 2017-06-09  35577700
# 2017-06-12  33170200
# 2017-06-13  20483400
# 2017-06-14  20808800
# 2017-06-15  18994200
# 2017-06-16  22882400
# 2017-06-19  19026500
# 2017-06-20  14743900
# 2017-06-21  15039800
# 2017-06-22  13005500
# 2017-06-23  18027000
# 2017-06-26  18049700
# 2017-06-27  19360800
# 2017-06-28  16719100
# 2017-06-29  23973500
# 2017-06-30  17666000
# 2017-07-03  13862700
# 2017-07-05  14334300
# 2017-07-06  14951800
# 2017-07-07  13615900
# 2017-07-10  13378700
# 2017-07-11  13667700
# 2017-07-12  22739400
# 2017-07-13  13929200
# 2017-07-14  16371200
# 2017-07-17  12858800
# 2017-07-18  23722900
# 2017-07-19  26273600

# %%
prediction = model.predict(x_input)
predicted_price = scaler.inverse_transform(prediction)
# Out:
# WARNING:tensorflow:6 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002046A1A3F60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step

# %%
print(f"Predicted Stock price for {prediction_date}: ${predicted_price[0][0]:.2f}")
price = get_stock_price(stock_symbol, prediction_date)
if price is not None:
    print(f"Actual Stock price for {prediction_date}: ${price:.2f}")
else:
    print(f"No data available for {prediction_date}")
# Out:
# Predicted Stock price for 2017-07-20: $162.96
# [*********************100%***********************]  1 of 1 completed
# Actual Stock price for 2017-07-20: $164.53

# %%
from keras.models import load_model
import pickle

# %%
with open('model.pkl', 'wb') as f:
    pickle.dump(model, f)

# %%
with open('model.pkl', 'rb') as f:
    model = pickle.load(f)
